# %%
# importing the data and using frictionless to describe the data
# You can infer, edit and save metadata of your data tables. It's a first step for ensuring data quality and usability. 
# Frictionless metadata includes general information about your data like textual description, as well as, field types and other tabular data details.
from pprint import pprint
from frictionless import describe
resource = describe('data/input/biomass_summary_errors.csv')
pprint(resource)
# Out:
# {'name': 'biomass_summary_errors',
#  'type': 'table',
#  'path': 'data/input/biomass_summary_errors.csv',
#  'scheme': 'file',
#  'format': 'csv',
#  'mediatype': 'text/csv',
#  'encoding': 'utf-8',
#  'schema': {'fields': [{'name': 'Site.ID', 'type': 'integer'},
#                        {'name': 'Biomasstype', 'type': 'string'},
#                        {'name': 'Site', 'type': 'string'},
#                        {'name': 'Invasion', 'type': 'string'},
#                        {'name': 'Treatment', 'type': 'string'},
#                        {'name': 'Weight_20by100_cm', 'type': 'string'},
#                        {'name': 'Treatment2', 'type': 'string'}]}}

# %%
#running a standard check

# %%
from frictionless import Checklist, validate

checklist = Checklist()
pprint(checklist.scope)
report = validate(resource) 
#print(report)
# Out:
# ['hash-count',
#  'byte-count',
#  'field-count',
#  'row-count',
#  'blank-header',
#  'extra-label',
#  'missing-label',
#  'blank-label',
#  'duplicate-label',
#  'incorrect-label',
#  'blank-row',
#  'primary-key',
#  'foreign-key',
#  'extra-cell',
#  'missing-cell',
#  'type-error',
#  'constraint-error',
#  'unique-error']

# %%
from frictionless import extract

rows = extract('data/input/biomass_summary_errors.csv')

# %%
#create a schema specific to the dataset, or to Envidat
from frictionless import Schema, fields, describe

#schema = describe('data/input/biomass_summary_errors.csv', type='schema') # from a resource path
schema = Schema.from_descriptor('data/input/table-schema.json') # from a descriptor path
#schema = Schema.from_descriptor({'fields': [{'name': 'id', 'type': 'integer'}]}) # from a descriptor
# Out:
# ---------------------------------------------------------------------------
# FrictionlessException                     Traceback (most recent call last)
# Cell In[61], line 5
#       2 from frictionless import Schema, fields, describe
#       4 #schema = describe('data/input/biomass_summary_errors.csv', type='schema') # from a resource path
# ----> 5 schema = Schema.from_descriptor('data/input/table-schema.json') # from a descriptor path
#       6 #schema = Schema.from_descriptor({'fields': [{'name': 'id', 'type': 'integer'}]}) # from a descriptor
#
# File /opt/conda/lib/python3.10/site-packages/frictionless/metadata/metadata.py:183, in Metadata.from_descriptor(cls, descriptor, allow_invalid, **options)
#     181 if isinstance(class_type, str):
#     182     type = class_type
# --> 183 Class = cls.metadata_select_class(type)
#     184 Error = Class.metadata_Error or platform.frictionless_errors.MetadataError
#     185 Class.metadata_transform(descriptor)
#
# File /opt/conda/lib/python3.10/site-packages/frictionless/metadata/metadata.py:293, in Metadata.metadata_select_class(cls, type)
#     291     note = f'unsupported type for "{cls.metadata_type}": {type}'
#     292     Error = cls.metadata_Error or platform.frictionless_errors.MetadataError
# --> 293     raise FrictionlessException(Error(note=note))
#     294 return cls
#
# FrictionlessException: [schema-error] Schema is not valid: unsupported type for "schema": ['string', 'object']

# %%
schema
# Out:
# {'fields': [{'name': 'Site.ID', 'type': 'integer'},
#             {'name': 'Biomasstype', 'type': 'string'},
#             {'name': 'Site', 'type': 'string'},
#             {'name': 'Invasion', 'type': 'string'},
#             {'name': 'Treatment', 'type': 'string'},
#             {'name': 'Weight_20by100_cm', 'type': 'string'},
#             {'name': 'Treatment2', 'type': 'string'}]}
