# %%
# importing the data and using frictionless to describe the data
# You can infer, edit and save metadata of your data tables. It's a first step for ensuring data quality and usability. 
# Frictionless metadata includes general information about your data like textual description, as well as, field types and other tabular data details.
from pprint import pprint
from frictionless import describe
resource = describe('data/input/biomass_summary_errors.csv')
pprint(resource)
# Out:
# {'name': 'biomass_summary_errors',
#  'type': 'table',
#  'path': 'data/input/biomass_summary_errors.csv',
#  'scheme': 'file',
#  'format': 'csv',
#  'mediatype': 'text/csv',
#  'encoding': 'utf-8',
#  'schema': {'fields': [{'name': 'Site.ID', 'type': 'integer'},
#                        {'name': 'Biomasstype', 'type': 'string'},
#                        {'name': 'Site', 'type': 'string'},
#                        {'name': 'Invasion', 'type': 'string'},
#                        {'name': 'Treatment', 'type': 'string'},
#                        {'name': 'Weight_20by100_cm', 'type': 'string'},
#                        {'name': 'Treatment2', 'type': 'string'}]}}

# %%
#running a standard check

# %%
from frictionless import Checklist, validate

checklist = Checklist()
pprint(checklist.scope)
report = validate(resource) 
print(report)
# Out:
# ['hash-count',
#  'byte-count',
#  'field-count',
#  'row-count',
#  'blank-header',
#  'extra-label',
#  'missing-label',
#  'blank-label',
#  'duplicate-label',
#  'incorrect-label',
#  'blank-row',
#  'primary-key',
#  'foreign-key',
#  'extra-cell',
#  'missing-cell',
#  'type-error',
#  'constraint-error',
#  'unique-error']
# {'valid': False,
#  'stats': {'tasks': 1, 'errors': 1, 'warnings': 0, 'seconds': 0.015},
#  'warnings': [],
#  'errors': [],
#  'tasks': [{'name': 'biomass_summary_errors',
#             'type': 'table',
#             'valid': False,
#             'place': 'data/input/biomass_summary_errors.csv',
#             'labels': ['Site.ID',
#                        'Biomasstype',
#                        'Site',
#                        'Invasion',
#                        'Treatment',
#                        'Weight_20by100_cm',
#                        'Treatment'],
#             'stats': {'errors': 1,
#                       'warnings': 0,
#                       'seconds': 0.015,
#                       'md5': 'de00a0fd25cd2412688ef1710d271ba3',
#                       'sha256': 'ff5450d3b8b9bfbb850fd26672d8ba87cf6f0aab186fe0b20c64767496e7dcb6',
#                       'bytes': 5194,
#                       'fields': 7,
#                       'rows': 110},
#             'warnings': [],
#             'errors': [{'type': 'duplicate-label',
#                         'title': 'Duplicate Label',
#                         'description': 'Two columns in the header row have the '
#                                        'same value. Column names should be '
#                                        'unique.',
#                         'message': 'Label "Treatment" in the header at '
#                                    'position "7" is duplicated to a label: at '
#                                    'position "5"',
#                         'tags': ['#table', '#header', '#label'],
#                         'note': 'at position "5"',
#                         'labels': ['Site.ID',
#                                    'Biomasstype',
#                                    'Site',
#                                    'Invasion',
#                                    'Treatment',
#                                    'Weight_20by100_cm',
#                                    'Treatment'],
#                         'rowNumbers': [1],
#                         'label': 'Treatment',
#                         'fieldName': 'Treatment2',
#                         'fieldNumber': 7}]}]}

# %%
with open('data/input/biomass_summary_errors.csv') as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 2
#       1 #extract data
# ----> 2 with open('country-3.csv') as file:
#       3     print(file.read())
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'country-3.csv'

# %%
#create a schema specific to the dataset, or to Envidat

# %%
from frictionless import Detector, describe

detector = Detector(field_missing_values=["", "n/a"])
resource = describe("data/input/capital-invalid.csv", detector=detector)
resource.schema.set_field_type("neighbor_id", "integer")
resource.schema.foreign_keys.append(
    {"fields": ["neighbor_id"], "reference": {"resource": "", "fields": ["id"]}}
)
resource.to_yaml("countries.resource.yaml")
# Out:
# ---------------------------------------------------------------------------
# FrictionlessException                     Traceback (most recent call last)
# Cell In[36], line 5
#       3 detector = Detector(field_missing_values=["", "n/a"])
#       4 resource = describe("data/input/capital-invalid.csv", detector=detector)
# ----> 5 resource.schema.set_field_type("neighbor_id", "integer")
#       6 resource.schema.foreign_keys.append(
#       7     {"fields": ["neighbor_id"], "reference": {"resource": "", "fields": ["id"]}}
#       8 )
#       9 resource.to_yaml("countries.resource.yaml")
#
# File /opt/conda/lib/python3.10/site-packages/frictionless/schema/schema.py:138, in Schema.set_field_type(self, name, type)
#     136 def set_field_type(self, name: str, type: str) -> Field:
#     137     """Set field type"""
# --> 138     return self.update_field(name, {"type": type})
#
# File /opt/conda/lib/python3.10/site-packages/frictionless/schema/schema.py:142, in Schema.update_field(self, name, descriptor)
#     140 def update_field(self, name: str, descriptor: types.IDescriptor) -> Field:
#     141     """Update field"""
# --> 142     prev_field = self.get_field(name)
#     143     field_index = self.fields.index(prev_field)
#     144     field_descriptor = prev_field.to_descriptor()
#
# File /opt/conda/lib/python3.10/site-packages/frictionless/schema/schema.py:123, in Schema.get_field(self, name)
#     121         return field
#     122 error = errors.SchemaError(note=f'field "{name}" does not exist')
# --> 123 raise FrictionlessException(error)
#
# FrictionlessException: [schema-error] Schema is not valid: field "neighbor_id" does not exist

# %%
from frictionless import Checklist, validate

checklist = Checklist()
pprint(checklist.scope)
report = validate(resource)  # we don't pass the checklist as the empty one is default
pprint(report.flatten(['type', 'message']))
# Out:
# ['hash-count',
#  'byte-count',
#  'field-count',
#  'row-count',
#  'blank-header',
#  'extra-label',
#  'missing-label',
#  'blank-label',
#  'duplicate-label',
#  'incorrect-label',
#  'blank-row',
#  'primary-key',
#  'foreign-key',
#  'extra-cell',
#  'missing-cell',
#  'type-error',
#  'constraint-error',
#  'unique-error']
# []

# %%
from frictionless import schema

# %%
schema resource
# Out:
#   Cell In[28], line 1
#     schema resource
#            ^
# SyntaxError: invalid syntax

# %%
frictionless schema resource
# Out:
#   Cell In[29], line 1
#     frictionless schema resource
#                  ^
# SyntaxError: invalid syntax
