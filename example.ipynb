# %%
from pprint import pprint
from frictionless import Checklist, validate

checklist = Checklist()
pprint(checklist.scope)
report = validate('data/input/capital-invalid.csv')  # we don't pass the checklist as the empty one is default
pprint(report.flatten(['type', 'message']))
# Out:
# ['hash-count',
#  'byte-count',
#  'field-count',
#  'row-count',
#  'blank-header',
#  'extra-label',
#  'missing-label',
#  'blank-label',
#  'duplicate-label',
#  'incorrect-label',
#  'blank-row',
#  'primary-key',
#  'foreign-key',
#  'extra-cell',
#  'missing-cell',
#  'type-error',
#  'constraint-error',
#  'unique-error']
# [['resource-error',
#   'The data resource has an error: path "/data/input/capital-invalid.csv" is '
#   'not safe']]
