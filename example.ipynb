# %%
from pprint import pprint
from frictionless import Checklist, validate

checklist = Checklist()
pprint(checklist.scope)
report = validate('/data/inputcapital-invalid.csv')  # we don't pass the checklist as the empty one is default
pprint(report.flatten(['type', 'message']))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from pprint import pprint
# ----> 2 from frictionless import Checklist, validate
#       4 checklist = Checklist()
#       5 pprint(checklist.scope)
#
# File ~/work/envidat_frictionless/frictionless.py:2
#       1 from pprint import pprint
# ----> 2 from frictionless import Checklist, validate
#       4 checklist = Checklist()
#       5 pprint(checklist.scope)
#
# ImportError: cannot import name 'Checklist' from partially initialized module 'frictionless' (most likely due to a circular import) (/home/jovyan/work/envidat_frictionless/frictionless.py)
